# %% [markdown]
# ![image.png](attachment:67d7a208-9b26-4773-b30d-8d6f5b385e60.png)

# %% [markdown]
# _Imagen tomada el proyecto [Entrenamiento Básico Python](https://entrenamiento-python-basico.readthedocs.io)_

# %% [markdown]
# # Programación Orientada a Objetos (POO) con Python

# %% [markdown]
# ## Definiendo los objetos y sus atributos a crear en base a la definición del problema o tarea a realizar.

# %% [markdown]
# ### Aplicar la programación orientada a objetos en Python para imprimir una lista de N personas (el ejemplo clásico!), donde cada persona deberá de incluir su nombre, edad y género.

# %% [markdown]
# 1. En base al enunciado del requerimiento o tarea o proyecto ubicar las palabras que son _sustantivos_ y crear una lista
#
# - ...

# %% [markdown]
# 2. Realizar un análisis de la lista para definir cuales pueden ser nuestros objetos y cuales pueden ser atributos, se puede emplear un software para diagramación o en su caso se puede usar un editor de texto o incluso Jupyter Lab.
#
# - obj1
#   - atr1
#   - atr2
#   ...

# %% [markdown]
# 3. Complementar los atributos faltantes, si ese fuera el caso

# %% [markdown]
# - obj1
#   - atr1
#   - atr2
#   - atr3

# %% [markdown]
# 4. Normalizar los nombres de objetos usando UpperCamelCase y atributos usando lowerCamelCase o palabras_separadas_por_guiones en minúsculas.

# %% [markdown]
# - Obj1
#   - atrUno
#   - atrDos
#   - atrN
# ...
